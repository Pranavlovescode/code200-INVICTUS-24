# %%
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb+srv://SAPP_SERVER:CCKB_2004@sapp.bba6dy5.mongodb.net/?retryWrites=true&w=majority')

#db = client['company_data']
#collection = db['glassdoor_jobs']
df = pd.read_csv('./glassdoor_jobs.csv')
df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
df.set_index('index', inplace=True)
df.drop(columns=['Founded', 'Industry','Competitors'], axis=1, inplace=True)
df.head(1)
data = df.to_dict('records')
#db.glassdoor_jobs.insert_many(data)
data
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[69], line 6
#       3 from pymongo import MongoClient
#       5 # Connect to MongoDB
# ----> 6 client = MongoClient('mongodb+srv://SAPP_SERVER:CCKB_2004@sapp.bba6dy5.mongodb.net/?retryWrites=true&w=majority')
#       7 db = client['company_data']
#       8 collection = db['glassdoor_jobs']
#
# File c:\Users\sathe\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\mongo_client.py:771, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     767 if timeout is not None:
#     768     timeout = common.validate_timeout_or_none_or_zero(
#     769         keyword_opts.cased_key("connecttimeoutms"), timeout
#     770     )
# --> 771 res = uri_parser.parse_uri(
#     772     entity,
#     773     port,
#     774     validate=True,
#     775     warn=True,
# ...

# %%
job_title = input("Enter job title keyword: ")
filtered_df = df[df['Job Title'].str.contains(job_title, case=False, na=False)]
filtered_df
# Out:
#                                           Job Title  \
# index
# 0                                    Data Scientist
# 1                         Healthcare Data Scientist
# 2                                    Data Scientist
# 3                                    Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 934                 Senior Insurance Data Scientist
# 935            Senior Data Science Systems Engineer
# 947                    Data Science Project Manager
# 949    Principal, Data Science - Advanced Analytics
# 953                            Data Science Manager
#
#                     Salary Estimate  \
# index
# 0        $53K-$91K (Glassdoor est.)
# 1       $63K-$112K (Glassdoor est.)
# 2        $80K-$90K (Glassdoor est.)
# 3        $56K-$97K (Glassdoor est.)
# 4       $86K-$143K (Glassdoor est.)
# ...                             ...
# 934    $107K-$173K (Glassdoor est.)
# ...
