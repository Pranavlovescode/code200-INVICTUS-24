# %%
import pandas as pd
# import matplotlib.pyplot as plt
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb+srv://SAPP_SERVER:CCKB_2004@sapp.bba6dy5.mongodb.net/?retryWrites=true&w=majority')
db = client['company_data']
#collection = db['glassdoor_jobs']
df = pd.read_csv('./glassdoor_jobs.csv')
df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
df.set_index('index', inplace=True)
df.drop(columns=['Founded', 'Industry','Competitors'], axis=1, inplace=True)

data = df.to_dict('records')
db.glassdoor_jobs.insert_many(data)
df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_6000\380436537.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                                Job Title  \
# index
# 0                                         Data Scientist
# 1                              Healthcare Data Scientist
# 2                                         Data Scientist
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 951                                 Senior Data Engineer
# 952    Project Scientist - Auton Lab, Robotics Institute
# 953                                 Data Science Manager
# 954                                        Data Engineer
# 955            Research Scientist – Security and Privacy
#
#                    Salary Estimate  \
# index
# 0       $53K-$91K (Glassdoor est.)
# 1      $63K-$112K (Glassdoor est.)
# 2       $80K-$90K (Glassdoor est.)
# 3       $56K-$97K (Glassdoor est.)
# 4      $86K-$143K (Glassdoor est.)
# ...                            ...
# 951    $72K-$133K (Glassdoor est.)
# 952     $56K-$91K (Glassdoor est.)
# 953    $95K-$160K (Glassdoor est.)
# 954                             -1
# 955    $61K-$126K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 0      Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1      What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2      KnowBe4, Inc. is a high growth information sec...     4.8
# 3      *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4      Data Scientist\r\nAffinity Solutions / Marketi...     2.9
# ...                                                  ...     ...
# 951    THE CHALLENGE\r\nEventbrite has a world-class ...     4.4
# 952    The Auton Lab at Carnegie Mellon University is...     2.6
# 953    Data Science ManagerResponsibilities:\r\n\r\nO...     3.2
# 954    Loading...\r\n\r\nTitle: Data Engineer\r\n\r\n...     4.8
# 955    Returning Candidate? Log back in to the Career...     3.6
#
#                                        Company Name         Location  \
# index
# 0                          Tecolote Research\r\n3.8  Albuquerque, NM
# 1      University of Maryland Medical System\r\n3.4    Linthicum, MD
# 2                                    KnowBe4\r\n4.8   Clearwater, FL
# 3                                       PNNL\r\n3.8     Richland, WA
# 4                         Affinity Solutions\r\n2.9     New York, NY
# ...                                             ...              ...
# 951                               Eventbrite\r\n4.4    Nashville, TN
# 952           Software Engineering Institute\r\n2.6   Pittsburgh, PA
# 953                             Numeric, LLC\r\n3.2    Allentown, PA
# 954                                     IGNW\r\n4.8       Austin, TX
# 955             Riverside Research Institute\r\n3.6  Beavercreek, OH
#
#             Headquarters                    Size       Type of ownership  \
# index
# 0             Goleta, CA   501 to 1000 employees       Company - Private
# 1          Baltimore, MD        10000+ employees      Other Organization
# 2         Clearwater, FL   501 to 1000 employees       Company - Private
# 3           Richland, WA  1001 to 5000 employees              Government
# 4           New York, NY     51 to 200 employees       Company - Private
# ...                  ...                     ...                     ...
# 951    San Francisco, CA  1001 to 5000 employees        Company - Public
# 952       Pittsburgh, PA   501 to 1000 employees    College / University
# 953      Chadds Ford, PA       1 to 50 employees       Company - Private
# 954         Portland, OR    201 to 500 employees       Company - Private
# 955        Arlington, VA   501 to 1000 employees  Nonprofit Organization
#
#                              Sector                           Revenue
# index
# 0               Aerospace & Defense         $50 to $100 million (USD)
# 1                       Health Care            $2 to $5 billion (USD)
# 2                 Business Services        $100 to $500 million (USD)
# 3      Oil, Gas, Energy & Utilities  $500 million to $1 billion (USD)
# 4                 Business Services          Unknown / Non-Applicable
# ...                             ...                               ...
# 951          Information Technology        $100 to $500 million (USD)
# 952                       Education          Unknown / Non-Applicable
# 953               Business Services           $5 to $10 million (USD)
# 954          Information Technology          $25 to $50 million (USD)
# 955                      Government         $50 to $100 million (USD)
#
# [956 rows x 11 columns]

# %%
df.head(50)
job_title = input("Enter job title keyword: ")
filtered_df = df[df['Job Title'].str.contains(job_title, case=False, na=False)]
filtered_df
# Out:
#                                                Job Title  \
# index
# 12                     Staff Data Scientist - Technology
# 94                     Staff Data Scientist - Technology
# 209                  MED TECH/LAB SCIENTIST - LABORATORY
# 247            MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
# 257    Medical Technologist / Clinical Laboratory Sci...
# 337                  MED TECH/LAB SCIENTIST - LABORATORY
# 367    Associate Scientist/Scientist, Process Analyti...
# 456            MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
# 496    Technology-Minded, Data Professional Opportuni...
# 527         Chief Scientist - Emerging Technology Center
# 682            MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
# 746    Technology-Minded, Data Professional Opportuni...
# 792         Chief Scientist - Emerging Technology Center
# 800            Tech Manager, Software Engineering - Data
# 824    Software Engineer Staff Scientist: Human Langu...
# 919            MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
#
#                         Salary Estimate  \
# index
# 12         $106K-$172K (Glassdoor est.)
# 94         $106K-$172K (Glassdoor est.)
# 209    $21-$34 Per Hour(Glassdoor est.)
# 247    $21-$34 Per Hour(Glassdoor est.)
# 257    $15-$25 Per Hour(Glassdoor est.)
# 337    $21-$34 Per Hour(Glassdoor est.)
# 367         $88K-$162K (Glassdoor est.)
# 456    $21-$34 Per Hour(Glassdoor est.)
# 496         $40K-$101K (Glassdoor est.)
# 527                                  -1
# 682    $21-$34 Per Hour(Glassdoor est.)
# 746         $40K-$101K (Glassdoor est.)
# 792                                  -1
# 800                                  -1
# 824         $74K-$124K (Glassdoor est.)
# 919    $21-$34 Per Hour(Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 12     Position Summary...\r\nDrives the execution of...     3.2
# 94     Position Summary...\r\nDrives the execution of...     3.2
# 209    Evening: 3P-1130P or Night Shift 11P-730A\r\n\...     3.6
# 247    Day Shift: 7A-330P. Holidays and every other w...     3.6
# 257    The incumbent performs a broad range of labora...     3.4
# 337    Evening: 3P-1130P or Night Shift 11P-730A\r\n\...     3.6
# 367    The Position\r\n\r\n\r\nWe are seeking a talen...     3.9
# 456    Day Shift: 7A-330P. Holidays and every other w...     3.6
# 496    At VU, we help Veterans buy homes. To make tha...     4.7
# 527    What We Do:\r\n\r\nAt the SEI Emerging Technol...     2.6
# 682    Day Shift: 7A-330P. Holidays and every other w...     3.6
# 746    At VU, we help Veterans buy homes. To make tha...     4.7
# 792    What We Do:\r\n\r\nAt the SEI Emerging Technol...     2.6
# 800    Job Overview:\r\n\r\nThe Manager of Software E...     3.2
# 824    Are you an experienced, passionate pioneer in ...     3.7
# 919    Day Shift: 7A-330P. Holidays and every other w...     3.6
#
#                                             Company Name  \
# index
# 12                                        Walmart\r\n3.2
# 94                                        Walmart\r\n3.2
# 209                              Beebe Healthcare\r\n3.6
# 247                              Beebe Healthcare\r\n3.6
# 257    Veterans Affairs, Veterans Health Administrati...
# 337                              Beebe Healthcare\r\n3.6
# 367                                     Genentech\r\n3.9
# 456                              Beebe Healthcare\r\n3.6
# 496                    Veterans United Home Loans\r\n4.7
# 527                Software Engineering Institute\r\n2.6
# 682                              Beebe Healthcare\r\n3.6
# 746                    Veterans United Home Loans\r\n4.7
# 792                Software Engineering Institute\r\n2.6
# 800                                        Macy's\r\n3.2
# 824                                      Raytheon\r\n3.7
# 919                              Beebe Healthcare\r\n3.6
#
#                       Location             Headquarters  \
# index
# 12                   Plano, TX          Bentonville, AR
# 94                   Plano, TX          Bentonville, AR
# 209                  Lewes, DE                Lewes, DE
# 247              Millville, DE                Lewes, DE
# 257            New Orleans, LA           Washington, DC
# 337                  Lewes, DE                Lewes, DE
# 367    South San Francisco, CA  South San Francisco, CA
# 456              Millville, DE                Lewes, DE
# 496               Columbia, MO             Columbia, MO
# 527             Pittsburgh, PA           Pittsburgh, PA
# 682              Millville, DE                Lewes, DE
# 746               Columbia, MO             Columbia, MO
# 792             Pittsburgh, PA           Pittsburgh, PA
# 800            Johns Creek, GA             New York, NY
# 824              Cambridge, MD              Waltham, MA
# 919              Millville, DE                Lewes, DE
#
#                          Size               Type of ownership  \
# index
# 12           10000+ employees                Company - Public
# 94           10000+ employees                Company - Public
# 209    1001 to 5000 employees          Nonprofit Organization
# 247    1001 to 5000 employees          Nonprofit Organization
# 257          10000+ employees                      Government
# 337    1001 to 5000 employees          Nonprofit Organization
# 367          10000+ employees  Subsidiary or Business Segment
# 456    1001 to 5000 employees          Nonprofit Organization
# 496    1001 to 5000 employees               Company - Private
# 527     501 to 1000 employees            College / University
# 682    1001 to 5000 employees          Nonprofit Organization
# 746    1001 to 5000 employees               Company - Private
# 792     501 to 1000 employees            College / University
# 800          10000+ employees                Company - Public
# 824          10000+ employees                Company - Public
# 919    1001 to 5000 employees          Nonprofit Organization
#
#                           Sector                     Revenue
# index
# 12                        Retail          $10+ billion (USD)
# 94                        Retail          $10+ billion (USD)
# 209                  Health Care  $100 to $500 million (USD)
# 247                  Health Care  $100 to $500 million (USD)
# 257                   Government    Unknown / Non-Applicable
# 337                  Health Care  $100 to $500 million (USD)
# 367    Biotech & Pharmaceuticals          $10+ billion (USD)
# 456                  Health Care  $100 to $500 million (USD)
# 496                      Finance    Unknown / Non-Applicable
# 527                    Education    Unknown / Non-Applicable
# 682                  Health Care  $100 to $500 million (USD)
# 746                      Finance    Unknown / Non-Applicable
# 792                    Education    Unknown / Non-Applicable
# 800                       Retail          $10+ billion (USD)
# 824          Aerospace & Defense          $10+ billion (USD)
# 919                  Health Care  $100 to $500 million (USD)
